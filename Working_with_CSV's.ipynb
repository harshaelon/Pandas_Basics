# %%
import pandas as pd

import numpy as np

# %%
#to read CSV files:

#pd.read_csv("abs path")

df=pd.read_csv("C:\\Users\\HARSHA\\OneDrive\\Desktop\\student_marks.csv")

# %%
print(df,type(df))
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# ...

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# ...

# %%
df.head(4)
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45

# %%
#before going into the functions we will look on two attributes : shape and ndim.

#ndim --> to specify no of dimensions (in general its 2-d).

# shape --> to tell no of rows and columns present in the given csv file.

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (10, 10)

# %%
# now lets look on different functions 

# head() --> gives the top 5 records , we can pass args. in default it gives top 5 records.

# syntax : df.head()

# %%
df.head(2)
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
#
#    History  Civics
# 0       89      65
# 1       58       2

# %%
df.head(8)
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# 5       87      52
# 6       64      61
# 7       76      87

# %%
# now lets look on different functions 

# tail() --> gives the bottom 5 records , we can pass args. in default it gives bottom 5 records.

# syntax : df.tail()

# %%
df.tail()
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics
# 5       87      52
# 6       64      61
# 7       76      87
# 8       63      89
# 9       46      77

# %%
df.tail(2)
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics
# 8       63      89
# 9       46      77

# %%
# now if we want some statistical data like mean , max, min etc. 

# we will be using the function describe()

# syntax : df.describe()

# %%
df.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
# next function is iterrows , if we want to get the records in line by line manner.

# syntax : df.iterrows().

# %%
for record in df.iterrows():
    #if(record[gender] =='M'):
    print(record)
# Out:
# (0, Unnamed: 0    John
# Gender           M
# Maths           55
# Physics         45
# Chemistry       56
# English         87
# Biology         21
# Economics       52
# History         89
# Civics          65
# Name: 0, dtype: object)
# (1, Unnamed: 0    Suresh
# Gender             M
# Maths             75
# Physics           96
# Chemistry         78
# English           64
# Biology           90
# Economics         61
# History           58
# Civics             2
# Name: 1, dtype: object)
# (2, Unnamed: 0    Ramesh
# Gender             M
# Maths             25
# Physics           54
# Chemistry         89
# English           76
# Biology           95
# Economics         87
# History           56
# Civics            74
# Name: 2, dtype: object)
# (3, Unnamed: 0    Jessica
# Gender              F
# Maths              78
# Physics            96
# Chemistry          86
# English            63
# Biology            54
# Economics          89
# History            75
# ...

# %%
df[::-1]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 9     Mukesh      M     96       46         77       83       58         83
# 8      Farha      F     55       63         89       75       78         75
# 7     Ritesh      M     54       76         87       56       25         56
# 6      pooja      F     55       64         61       58       75         58
# 5       Annu      F     45       87         52       89       55         89
# 4   Jennifer      F     58       96         78       46       96         77
# 3    Jessica      F     78       96         86       63       54         89
# 2     Ramesh      M     25       54         89       76       95         87
# 1     Suresh      M     75       96         78       64       90         61
# 0       John      M     55       45         56       87       21         52
#
#    History  Civics
# 9       46      77
# 8       63      89
# 7       76      87
# 6       64      61
# 5       87      52
# ...

# %%
# important thing is we can perform slicing and indexing on the dataframe object.

# %%
df[0:4]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45

# %%
# next we will look on slicing with steps and reterival with column.

# %%
df["gender"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gender'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[0]["gender"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[2:7]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
#
#    History  Civics
# 2       56      74
# 3       75      45
# 4       83      53
# 5       87      52
# 6       64      61

# %%
df[2:7]["History"]
# Out:
# 2    56
# 3    75
# 4    83
# 5    87
# 6    64
# Name: History, dtype: int64

# %%
df[2:7][["Unnamed: 0","Maths"]]
# Out:
#   Unnamed: 0  Maths
# 2     Ramesh     25
# 3    Jessica     78
# 4   Jennifer     58
# 5       Annu     45
# 6      pooja     55

# %%
df[1:8][["Unnamed: 0","Civics"]]
# Out:
#   Unnamed: 0  Civics
# 1     Suresh       2
# 2     Ramesh      74
# 3    Jessica      45
# 4   Jennifer      53
# 5       Annu      52
# 6      pooja      61
# 7     Ritesh      87

# %%
#the important loc and iloc

#loc : this is a function where it gets data similar to that of indexing. 

# --> here it retrives both start and stop indexes.

# while reteriving colums we have to use their numbers or internal numbers.


# syntax : df.loc[start:stop:step]["col1":"col_n"]

# %%
df.loc[1:8:2,["Unnamed: 0","Civics"]]
# Out:
#   Unnamed: 0  Civics
# 1     Suresh       2
# 3    Jessica      45
# 5       Annu      52
# 7     Ritesh      87

# %%
df.iloc[1:9]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
#
#    History  Civics
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# 5       87      52
# 6       64      61
# 7       76      87
# 8       63      89

# %% [markdown]
# what we have seen yesterday , a small recap.

# %%
# creation of a dataframe 

# syntax of the dataframe ---> df=pd.DataFrame(object,index,columns,dtype)

# reading or loading CSV files into the dataframe.
# syntax : df=pd.read_csv("absolute path should be given.")

# the attributes of the dataframe --> shape and ndim.

# different functions of the dataframe :

# 1.head() ---> gives the top 5 records from the dataframe , can pass args.
# syntax : ---> df.head().

# 2. tail() ---> gives the bottom 5 records from the dataframe , can pass arguments.
# syntax ---> df.tail().

# 3.describe() ---> performs statistical operations such as max , min , count of variables.
# syntax ---> df.describe().

# 4. iterrows() ---> responsible for reterival of the rows.
# syntax ---> for record in df.iterrows():
            #      print(record).
    
# we can perform slicing and indexing operations on the dataframe.

# loc and iloc ---> very important functions.

# loc ---> reterival but includes both start and stop data.
#iloc ---> reterival but fetches records until stop-1.

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# ...

# %%
df[1:5:2]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 1     Suresh      M     75       96         78       64       90         61
# 3    Jessica      F     78       96         86       63       54         89
#
#    History  Civics
# 1       58       2
# 3       75      45

# %%
df.loc[1:9,["Unnamed: 0","Gender","Maths"]]
# Out:
#   Unnamed: 0 Gender  Maths
# 1     Suresh      M     75
# 2     Ramesh      M     25
# 3    Jessica      F     78
# 4   Jennifer      F     58
# 5       Annu      F     45
# 6      pooja      F     55
# 7     Ritesh      M     54
# 8      Farha      F     55
# 9     Mukesh      M     96

# %%
df.head()
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53

# %%
df.tail(4)
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics
# 6       64      61
# 7       76      87
# 8       63      89
# 9       46      77

# %%
df.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
ld=pd.Series([10,20,30,40,50])

# %%
print(ld,type(ld))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# ...

# %%
df.loc[1:9:1,"Unnamed: 0":"English"]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English
# 1     Suresh      M     75       96         78       64
# 2     Ramesh      M     25       54         89       76
# 3    Jessica      F     78       96         86       63
# 4   Jennifer      F     58       96         78       46
# 5       Annu      F     45       87         52       89
# 6      pooja      F     55       64         61       58
# 7     Ritesh      M     54       76         87       56
# 8      Farha      F     55       63         89       75
# 9     Mukesh      M     96       46         77       83

# %%
df.loc[1:5,"Unnamed: 0":"Civics"]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
#
#    History  Civics
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# 5       87      52

# %%
df.loc[1:5,"Maths":"Civics":2]
# Out:
#    Maths  Chemistry  Biology  History
# 1     75         78       90       58
# 2     25         89       95       56
# 3     78         86       54       75
# 4     58         78       96       83
# 5     45         52       55       87

# %%
df.iloc[1:5,[0,4,5]]
# Out:
#   Unnamed: 0  Chemistry  English
# 1     Suresh         78       64
# 2     Ramesh         89       76
# 3    Jessica         86       63
# 4   Jennifer         78       46

# %%
df.iloc[2,[0,1,2,3,4,5]]
# Out:
# Unnamed: 0    Ramesh
# Gender             M
# Maths             25
# Physics           54
# Chemistry         89
# English           76
# Name: 2, dtype: object

# %%
df.iloc[1:8,0:8:2]
# Out:
#   Unnamed: 0  Maths  Chemistry  Biology
# 1     Suresh     75         78       90
# 2     Ramesh     25         89       95
# 3    Jessica     78         86       54
# 4   Jennifer     58         78       96
# 5       Annu     45         52       55
# 6      pooja     55         61       75
# 7     Ritesh     54         87       25

# %%
df.iloc[3,[0,4,6]]
# Out:
# Unnamed: 0    Jessica
# Chemistry          86
# Biology            54
# Name: 3, dtype: object

# %%
df.iloc[[0,2,4]] # will give us specified records.
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 2     Ramesh      M     25       54         89       76       95         87
# 4   Jennifer      F     58       96         78       46       96         77
#
#    History  Civics
# 0       89      65
# 2       56      74
# 4       83      53

# %%
# until here we have seen on how to access records .

# now lets try to look how to create new rows.

# %%
# syntax : df["total"]= default value

# syntax : df["total"]=Math expression

# %%
df["Total"]=0

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics  Total
# 0       89      65      0
# 1       58       2      0
# 2       56      74      0
# ...

# %%
df["Total"]=df["Maths"]+df["Physics"]+df["Chemistry"]+df["English"]+df["Biology"]+df["Economics"]+df["History"]+df["Civics"]

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics  Total
# 0       89      65    470
# 1       58       2    524
# 2       56      74    556
# ...

# %%
df["Percentage"]=round((df["Total"]/800)*100,4)

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics  Total  Percentage
# 0       89      65    470      58.750
# 1       58       2    524      65.500
# ...

# %%
df.loc[1:8,["Maths"]]
# Out:
#    Maths
# 1     75
# 2     25
# 3     78
# 4     58
# 5     45
# 6     55
# 7     54
# 8     55

# %%
df.iloc[1:8,[1]]
# Out:
#   Gender
# 1      M
# 2      M
# 3      F
# 4      F
# 5      F
# 6      F
# 7      M

# %%
df["Maths"]>75
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# Name: Maths, dtype: bool

# %%
df.loc[df["Maths"]>75,["Unnamed: 0","Maths"]]
# Out:
#   Unnamed: 0  Maths
# 3    Jessica     78
# 9     Mukesh     96

# %%
df.loc[df["Percentage"]>65,"Unnamed: 0":"Civics"]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# 5       87      52
# 8       63      89
# 9       46      77

# %%
df["Grade"]=None

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics  Total  Percentage Grade
# 0       89      65    470      58.750  None
# ...

# %%
df.loc[(df["Percentage"]>70),["Grade"]]="First"

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics  Total  Percentage  Grade
# 0       89      65    470      58.750  First
# ...

# %%
df.loc[(df["Percentage"]>65) & (df["Percentage"]<70),["Grade"]]="Second"

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics  Total  Percentage   Grade
# 0       89      65    470      58.750   First
# ...

# %%
df.loc[(df["Percentage"]<65),["Grade"]]="Third"

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics  Total  Percentage   Grade
# 0       89      65    470      58.750   Third
# ...

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics  Total  Percentage   Grade
# 0       89      65    470      58.750   Third
# ...

# %%
df["Grade"]=="First"
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: Grade, dtype: bool

# %%
df.loc[df["Grade"]=="First"]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics  Total  Percentage  Grade
# 3       75      45    586      73.250  First
# 4       83      53    587      73.375  First
# 8       63      89    587      73.375  First
# 9       46      77    566      70.750  First
