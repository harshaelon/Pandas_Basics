# %%
#pandas datastructures : 

# 1. Series : df=pd.Series(object,index,datatype)

# 2. DataFrame : df=pd.DataFrame(object,rowIndex,Columns,dtype)

#different types of attributes and functions : 

# attributes : ndim,shape

# functions : head(),tail(),describe(),df[start:stop:step],df.loc[start:stop:step],df.iloc[start,stop-1]


# To read csv_files : df.read_csv("absolute path")

# %%
list1=[10,20,30,40,50]

# %%
import pandas as pd

import numpy as np

# %%
s=pd.Series(list1)

# %%
print(s,type(s))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s1=pd.Series(list1,["Item1","item2","Item3","item4","item5"],dtype=float)

# %%
s1
# Out:
# Item1    10.0
# item2    20.0
# Item3    30.0
# item4    40.0
# item5    50.0
# dtype: float64

# %%
# we cant pass one Series object to another series object, but we can pass a nd - array to a series object.

# %%
n1=np.array(list1)

# %%
n1
# Out:
# array([10, 20, 30, 40, 50])

# %%
s2=pd.Series(n1)

# %%
s2
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int32

# %%
s2[1]
# Out:
# 20

# %%
s2[::-1]
# Out:
# 4    50
# 3    40
# 2    30
# 1    20
# 0    10
# dtype: int32

# %%
# Series datastructure supports both indexing and slicing.

# %%
# DataFrame : it consists of rows , columns, datasets.

# %%
# creation of a dataframe :
# syntax : df=pd.DataFrame(obj,rowIndex,columns,dtype)

# %%
list2={10:1,20:2,30:3}

# %%
df=pd.DataFrame(list2,[0,1,2],["value","stock"])

# %%
df
# Out:
#   value stock
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN

# %%
list3=[["SBI",5.6,5.7,5.8],["HDFC",6.6,6.7,6.8],["ICICI",7.5,7.6,7.7]]

# %%
df=pd.DataFrame(list3,[1,2,3],["Banks","personal_loan","home_loan","Education_loan"])

# %%
df
# Out:
#    Banks  personal_loan  home_loan  Education_loan
# 1    SBI            5.6        5.7             5.8
# 2   HDFC            6.6        6.7             6.8
# 3  ICICI            7.5        7.6             7.7

# %%
df
# Out:
#    Banks  personal_loan  home_loan  Education_loan
# 1    SBI            5.6        5.7             5.8
# 2   HDFC            6.6        6.7             6.8
# 3  ICICI            7.5        7.6             7.7

# %%
df["personal_loan"]
# Out:
# 1    5.6
# 2    6.6
# 3    7.5
# Name: personal_loan, dtype: float64

# %%
# we can set the row index name as a column one, using df.set_index("name")

# %%
df.set_index("Banks")
# Out:
#        personal_loan  home_loan  Education_loan
# Banks
# SBI              5.6        5.7             5.8
# HDFC             6.6        6.7             6.8
# ICICI            7.5        7.6             7.7

# %%
# to read CSV's : Syntax : df=od.read_csv("ABS_path")

# to read Excel_sheets : Syntax -> df=pd.read_excel("ABS_path")

# %%
df1=pd.read_excel("D://Capgemini proj_details_Tuesday (1).xlsx")

# %%
df1
# Out:
#       Unnamed: 0                     Unnamed: 1               Unnamed: 2  \
# 0            NaN                            NaN                      NaN
# 1            NaN                            NaN                      NaN
# 2            NaN                            NaN                      NaN
# 3            NaN                            NaN                      NaN
# 4            NaN                            NaN                      NaN
# 5   Batch Number                  Project Title            Batch members
# 6            NaN                            NaN                      NaN
# 7            NaN                            NaN                      NaN
# 8            NaN                            NaN                      NaN
# 9            NaN                            NaN                      NaN
# 10           NaN                            NaN                      NaN
# 11           NaN                            NaN                      NaN
# ...

# %%
df=pd.read_csv("C:/Users/HARSHA/OneDrive/Desktop/student_marks.csv")

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# ...

# %%
df.head()
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53

# %%
df.tail()
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics
# 5       87      52
# 6       64      61
# 7       76      87
# 8       63      89
# 9       46      77

# %%
df.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# ...

# %%
df[1:5]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
#
#    History  Civics
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53

# %%
df[1:8:2]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 1     Suresh      M     75       96         78       64       90         61
# 3    Jessica      F     78       96         86       63       54         89
# 5       Annu      F     45       87         52       89       55         89
# 7     Ritesh      M     54       76         87       56       25         56
#
#    History  Civics
# 1       58       2
# 3       75      45
# 5       87      52
# 7       76      87

# %%
# loc ---> one type of accessing tool --> to access data.

# %%
df.loc[1:8]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
#
#    History  Civics
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# 5       87      52
# 6       64      61
# 7       76      87
# 8       63      89

# %%
df.loc[1:8,["Gender","Civics"]]
# Out:
#   Gender  Civics
# 1      M       2
# 2      M      74
# 3      F      45
# 4      F      53
# 5      F      52
# 6      F      61
# 7      M      87
# 8      F      89

# %%
df.loc[1:8,"Gender":"Biology"]
# Out:
#   Gender  Maths  Physics  Chemistry  English  Biology
# 1      M     75       96         78       64       90
# 2      M     25       54         89       76       95
# 3      F     78       96         86       63       54
# 4      F     58       96         78       46       96
# 5      F     45       87         52       89       55
# 6      F     55       64         61       58       75
# 7      M     54       76         87       56       25
# 8      F     55       63         89       75       78

# %%
#iloc

df.iloc[1:8]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
#
#    History  Civics
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# 5       87      52
# 6       64      61
# 7       76      87

# %%
df.iloc[[2,3,4,5]]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
#
#    History  Civics
# 2       56      74
# 3       75      45
# 4       83      53
# 5       87      52

# %%
df.iloc[1:8,1:4]
# Out:
#   Gender  Maths  Physics
# 1      M     75       96
# 2      M     25       54
# 3      F     78       96
# 4      F     58       96
# 5      F     45       87
# 6      F     55       64
# 7      M     54       76

# %%
df.iloc[1:8,0:9]
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
#
#    History
# 1       58
# 2       56
# 3       75
# 4       83
# 5       87
# 6       64
# 7       76

# %%
df.loc[df["Gender"]=='M',['Maths','Gender']]
# Out:
#    Maths Gender
# 0     55      M
# 1     75      M
# 2     25      M
# 7     54      M
# 9     96      M

# %%
df["Grade"]=None

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics Grade
# 0       89      65  None
# 1       58       2  None
# 2       56      74  None
# 3       75      45  None
# ...

# %%
df["Percent"]=None

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics Grade Percent
# 0       89      65  None    None
# 1       58       2  None    None
# ...

# %%
df["Total"]=df['Maths']+df['Physics']+df['Chemistry']+df['English']+df['Biology']+df['Economics']+df['History']+df['Civics']

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics Grade Percent  Total
# 0       89      65  None    None    470
# 1       58       2  None    None    524
# ...

# %%
df.loc[(df['Total']//8),df['Percent']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29076\2643986852.py in <module>
# ----> 1 df.loc[(df['Total']//8),df['Percent']]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1145         # ugly hack for GH #836
#    1146         if self._multi_take_opportunity(tup):
# -> 1147             return self._multi_take(tup)
#    1148
#    1149         return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df['Percent']=(df['Total']/8)

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics Grade  Percent  Total
# 0       89      65  None   58.750    470
# 1       58       2  None   65.500    524
# ...

# %%
df.loc[df['Percent']>70,['Grade']]='First'

# %%
#df.loc[df['Percent']>60 & df['Percent']<69,['Grade']]='Second'

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics   Grade  Percent  Total
# 0       89      65   Third   58.750    470
# 1       58       2  Second   65.500    524
# ...

# %%
df.loc[(df['Percent']>60) & (df['Percent']<=70),['Grade']]='Second'

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics   Grade  Percent  Total
# 0       89      65   Third   58.750    470
# 1       58       2  Second   65.500    524
# ...

# %%
df.loc[df['Percent']<60,['Grade']]='Third'

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics   Grade  Percent  Total
# 0       89      65   Third   58.750    470
# 1       58       2  Second   65.500    524
# ...

# %%
df.to_csv("C:/Users/HARSHA/OneDrive/Desktop/student_marks.csv")

# %%
df
# Out:
#   Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0       John      M     55       45         56       87       21         52
# 1     Suresh      M     75       96         78       64       90         61
# 2     Ramesh      M     25       54         89       76       95         87
# 3    Jessica      F     78       96         86       63       54         89
# 4   Jennifer      F     58       96         78       46       96         77
# 5       Annu      F     45       87         52       89       55         89
# 6      pooja      F     55       64         61       58       75         58
# 7     Ritesh      M     54       76         87       56       25         56
# 8      Farha      F     55       63         89       75       78         75
# 9     Mukesh      M     96       46         77       83       58         83
#
#    History  Civics   Grade  Percent  Total
# 0       89      65   Third   58.750    470
# 1       58       2  Second   65.500    524
# ...
